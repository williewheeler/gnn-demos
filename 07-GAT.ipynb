# %% [markdown]
# Notebook based on _Hands-On Graph Neural Networks Using Python_, by Maxime Labonne.
#
# # Ch 7. Graph Attention Networks
